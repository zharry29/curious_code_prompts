# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./num_shots.csv')

# %%
df
# Out:
#     performance  num_shot              Task
# 0         0.574        14              ANLI
# 1         0.562        32              ANLI
# 2         0.598        72              ANLI
# 3         0.373         5            OpenPI
# 4         0.400        12            OpenPI
# 5         0.470         2          HotpotQA
# 6         0.323         5          HotpotQA
# 7         0.613        30        WinoGrande
# 8         0.607        66        WinoGrande
# 9         0.589       134        WinoGrande
# 10        0.115         3    CNN/Daily Mail
# 11        0.117         7    CNN/Daily Mail
# 12        0.122        14    CNN/Daily Mail
# 13        0.565         8             SQuAD
# 14        0.604        17             SQuAD
# 15        0.646        37             SQuAD
# 16        0.141         5              XSUM
# 17        0.145        10              XSUM
# 18        0.144        21              XSUM
# 19        0.684         9         HellaSwag
# 20        0.652        18         HellaSwag
# 21        0.489        37         HellaSwag
# 22        0.915        23  WikiHow-GoalStep
# 23        0.924        47  WikiHow-GoalStep
# 24        0.924        94  WikiHow-GoalStep
# 25        0.687        27  WikiHow-Temporal
# 26        0.622        55  WikiHow-Temporal
# 27        0.659       100  WikiHow-Temporal
# 28        0.933         7              IMDb
# 29        0.945        14              IMDb
# 30        0.946        29              IMDb
# 31        0.923        13              Yelp
# 32        0.924        25              Yelp
# 33        0.919        49              Yelp

# %%
classes = list(set(df['Task'].values))

# %%
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
plt.figure(figsize=(8, 4), dpi=120)
sns.lineplot(data=df, x='num_shot', y='performance', hue='Task', marker="o")
plt.legend(bbox_to_anchor=(1.02, 1.), loc='upper left', borderaxespad=0)
plt.xscale('log')
plt.ylim(0, 1.)
plt.ylabel('Performance Score')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')
